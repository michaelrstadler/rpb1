# %% [markdown]
# ## Figure W1 - Motivation
#
# #### Enter filenames

# %%
figuredata_folder = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation'
png_3d_rpb1 = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220318-rpb1-gfp-em2-05-Denoising-highres.png'
png_3d_h2b = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220610-h2b-gfp-em2-12-Denoising-highres.png'
png_3d_zld = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220323-zld-mneon-em1-14-1.png'
png_3d_bcd = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220526-bcd-gfp-em3-04-Denoising-highres.png'
png_2d_zld = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220523-zld-mneon-em1-15.png'
png_2d_rpb1 = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220318-rpb1-gfp-em2-05.png'
png_2d_h2b = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220610-h2b-gfp-em2-12.png'
png_2d_bcd = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/20220526-bcd-gfp-em3-05.png'

png_strategy_overview = '/Users/michaelstadler/Bioinformatics/Projects/rpb1/data/figuredata/W1-motivation/strategy_overview.png'

# %%
from importlib import reload
import flymovie as fm
import cnn_models.evaluate_models as ev
from flymovie.simnuc import Sim
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import seaborn as sns
from importlib import reload
import umap
import scipy.ndimage as ndi
import skimage as ski
import matplotlib.image as mpimg
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### Set up files, define subplotting functions.

# %%
outfile = os.path.join(figuredata_folder, 'figure-w1-motivation.png')

# %% [markdown]
# #### Make subplots, save.

# %% [markdown]
# #### Assemble final figure

# %%
fig = plt.figure(constrained_layout=False, facecolor='1', figsize=(12,12))
plt.rcParams.update({'font.sans-serif':'Deja Vu'})
plt.rcParams.update({'font.weight':'heavy'})
v_level1 = 0.72
v_level2 = 0.58
v_level3 = 0.12

h_level1 = 0.05
h_level2 = 0.265
h_level3 = 0.54
h_level4 = 0.755

# Add 3D images.
ax = fig.add_axes((h_level1,v_level1,0.20,0.125))
img = mpimg.imread(png_3d_zld)
ax.imshow(img, aspect='auto')
ax.axis('off')

ax = fig.add_axes((h_level1,v_level2,0.20,0.125))
img = mpimg.imread(png_3d_rpb1)
ax.imshow(img, aspect='auto')
ax.axis('off')

ax = fig.add_axes((h_level2,v_level1,0.20,0.125))
img = mpimg.imread(png_3d_bcd)
ax.imshow(img, aspect='auto')
ax.axis('off')

ax = fig.add_axes((h_level2,v_level2,0.20,0.125))
img = mpimg.imread(png_3d_h2b)
ax.imshow(img, aspect='auto')
ax.axis('off')

# Add 2D images.
ax = fig.add_axes((h_level3,v_level1,0.20,0.125))
img = mpimg.imread(png_2d_zld)
ax.imshow(img, aspect='auto')
ax.axis('off')

ax = fig.add_axes((h_level3,v_level2,0.20,0.125))
img = mpimg.imread(png_2d_rpb1)
ax.imshow(img, aspect='auto')
ax.axis('off')

ax = fig.add_axes((h_level4,v_level1,0.20,0.125))
img = mpimg.imread(png_2d_bcd)
ax.imshow(img, aspect='auto')
ax.axis('off')

ax = fig.add_axes((h_level4,v_level2,0.20,0.125))
img = mpimg.imread(png_2d_h2b)
ax.imshow(img, aspect='auto')
ax.axis('off')

ax = fig.add_axes((h_level1 + 0.02,v_level3,1.0,0.50))
img = mpimg.imread(png_strategy_overview)
ax.imshow(img, aspect='equal')
ax.axis('off')

# Add general figure text.
h_margin = -0.03
v_margin = 0.15
h_margin_center = 0.19
v_margin_center = 0.14
v_margin_bottom_label = 0.54
fig.text(h_level1 + h_margin, v_level1 + v_margin,  'A', size=20)
fig.text(h_level3 + h_margin, v_level1 + v_margin,  'B', size=20)
fig.text(h_level1 + h_margin, v_margin_bottom_label,  'C', size=20)
fig.text(h_level1 + h_margin_center, v_level1 + v_margin_center,  '3D', size=22)
fig.text(h_level3 + h_margin_center, v_level1 + v_margin_center, '2D', size=22)

fig.text(0.45, 0.95, 'Figure 1', size=26)

# Add protein labels.
h_margin = 0.004
v_margin = 0.006
size=14
fig.text(h_level1 + h_margin, v_level1 + v_margin,  'Zld', size=size, color='white')
fig.text(h_level1 + h_margin, v_level2 + v_margin,  'Rpb1', size=size, color='white')
fig.text(h_level2 + h_margin, v_level1 + v_margin,  'Bcd', size=size, color='white')
fig.text(h_level2 + h_margin, v_level2 + v_margin,  'H2B', size=size, color='white')

fig.text(h_level3 + h_margin, v_level1 + v_margin,  'Zld', size=size, color='white')
fig.text(h_level3 + h_margin, v_level2 + v_margin,  'Rpb1', size=size, color='white')
fig.text(h_level4 + h_margin, v_level1 + v_margin,  'Bcd', size=size, color='white')
fig.text(h_level4 + h_margin, v_level2 + v_margin,  'H2B', size=size, color='white')
fig.savefig(outfile,dpi=100)
